# %%
from google.colab import drive
import os

# Check if the mount point exists and is not empty, then remove its contents
mountpoint = '/content/drive'

drive.mount(mountpoint)
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
from tensorflow.keras import backend as K

def focal_loss_fixed(y_true, y_pred, gamma=2., alpha=.25):
    """
    Focal loss for binary classification.
    """
    eps = K.epsilon()
    y_pred = K.clip(y_pred, eps, 1. - eps)

    loss_pos = -alpha * K.pow(1 - y_pred, gamma) * y_true * K.log(y_pred)
    loss_neg = -(1 - alpha) * K.pow(y_pred, gamma) * (1 - y_true) * K.log(1 - y_pred)

    return K.sum(loss_pos + loss_neg, axis=1)

# %%
from tensorflow.keras.models import load_model
import os

ensemble_dir = "/content/drive/MyDrive/Project/solarPanelDefectDetection_Binary/balancedClasses"
ensemble_models = []

for root, dirs, files in os.walk(ensemble_dir):
    for f in files:
        if f.endswith(".keras"):
            path = os.path.join(root, f)
            print(f"Loading {path}")
            model = load_model(path, custom_objects={'focal_loss_fixed': focal_loss_fixed})
            ensemble_models.append(model)

print(f"Successfully loaded {len(ensemble_models)} ensemble models.")
# Out:
# Loading /content/drive/MyDrive/Project/solarPanelDefectDetection_Binary/balancedClasses/model_results/SplitBalanced_batch_1_ResNet50.keras
# Loading /content/drive/MyDrive/Project/solarPanelDefectDetection_Binary/balancedClasses/model_results/SplitBalanced_batch_1_VGG16.keras
# Loading /content/drive/MyDrive/Project/solarPanelDefectDetection_Binary/balancedClasses/model_results/SplitBalanced_batch_1_InceptionV3.keras
# Loading /content/drive/MyDrive/Project/solarPanelDefectDetection_Binary/balancedClasses/model_results/SplitBalanced_batch_1_EfficientNetB0.keras
# Loading /content/drive/MyDrive/Project/solarPanelDefectDetection_Binary/balancedClasses/model_results/SplitBalanced_batch_1_MobileNetV2.keras
# Loading /content/drive/MyDrive/Project/solarPanelDefectDetection_Binary/balancedClasses/model_results/SplitBalanced_batch_2_ResNet50.keras
# Loading /content/drive/MyDrive/Project/solarPanelDefectDetection_Binary/balancedClasses/model_results/SplitBalanced_batch_2_VGG16.keras
# Loading /content/drive/MyDrive/Project/solarPanelDefectDetection_Binary/balancedClasses/model_results/SplitBalanced_batch_2_InceptionV3.keras
# Loading /content/drive/MyDrive/Project/solarPanelDefectDetection_Binary/balancedClasses/model_results/SplitBalanced_batch_2_EfficientNetB0.keras
# Loading /content/drive/MyDrive/Project/solarPanelDefectDetection_Binary/balancedClasses/model_results/SplitBalanced_batch_2_MobileNetV2.keras
# Loading /content/drive/MyDrive/Project/solarPanelDefectDetection_Binary/balancedClasses/model_results/SplitBalanced_batch_3_ResNet50.keras
# Loading /content/drive/MyDrive/Project/solarPanelDefectDetection_Binary/balancedClasses/model_results/SplitBalanced_batch_3_VGG16.keras
# Loading /content/drive/MyDrive/Project/solarPanelDefectDetection_Binary/balancedClasses/model_results/SplitBalanced_batch_3_InceptionV3.keras
# Loading /content/drive/MyDrive/Project/solarPanelDefectDetection_Binary/balancedClasses/model_results/SplitBalanced_batch_3_EfficientNetB0.keras
# Loading /content/drive/MyDrive/Project/solarPanelDefectDetection_Binary/balancedClasses/model_results/SplitBalanced_batch_3_MobileNetV2.keras
# Loading /content/drive/MyDrive/Project/solarPanelDefectDetection_Binary/balancedClasses/model_results/SplitBalanced_batch_4_ResNet50.keras
# Loading /content/drive/MyDrive/Project/solarPanelDefectDetection_Binary/balancedClasses/model_results/SplitBalanced_batch_4_VGG16.keras
# Loading /content/drive/MyDrive/Project/solarPanelDefectDetection_Binary/balancedClasses/model_results/SplitBalanced_batch_4_InceptionV3.keras
# Loading /content/drive/MyDrive/Project/solarPanelDefectDetection_Binary/balancedClasses/model_results/SplitBalanced_batch_4_EfficientNetB0.keras
# Loading /content/drive/MyDrive/Project/solarPanelDefectDetection_Binary/balancedClasses/model_results/SplitBalanced_batch_4_MobileNetV2.keras
# Loading /content/drive/MyDrive/Project/solarPanelDefectDetection_Binary/balancedClasses/model_results/SplitBalanced_batch_3_Ensemble.keras
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:802: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 90 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:802: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 70 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:802: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 52 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:802: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 74 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Successfully loaded 21 ensemble models.
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:802: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 82 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
# !ls /content/drive/MyDrive/Project/solarPanelDefectDetection_Binary/binaryClassification/test/defective/
# Out:
# 'Electrical (14).jpg'  'Electrical (32).jpg'  'Electrical (7).jpg'
# 'Electrical (15).jpg'  'Electrical (39).jpg'  'Physical (14).jpg'
# 'Electrical (16).jpg'  'Electrical (56).jpg'  'Physical (33).jpg'
# 'Electrical (28).jpg'  'Electrical (58).jpg'  'Physical (42).jpg'
# 'Electrical (29).jpg'  'Electrical (62).jpg'  'Physical (53).jpg'
# 'Electrical (30).jpg'  'Electrical (6).jpg'   'Physical (64).jpg'

# %%
# !ls /content/drive/MyDrive/Project/solarPanelDefectDetection_Binary/binaryClassification/test/non_defective/
# Out:
# 'Bird (104).jpg'  'Bird (55).jpg'    'Clean (63).jpg'  'Snow (114).jpg'
# 'Bird (121).jpg'  'Bird (70).jpg'    'Clean (67).jpg'  'Snow (14).jpg'
# 'Bird (123).jpg'  'Bird (74).jpg'    'Clean (70).jpg'  'Snow (15).jpg'
# 'Bird (126).jpg'  'Bird (77).jpg'    'Clean (84).jpg'  'Snow (1).jpg'
# 'Bird (128).jpg'  'Clean (103).jpg'  'Clean (87).jpg'  'Snow (26).jpg'
# 'Bird (139).jpg'  'Clean (11).jpg'   'Clean (95).jpg'  'Snow (28).JPG'
# 'Bird (140).jpg'  'Clean (125).jpg'  'Clean (9).jpg'   'Snow (41).jpg'
# 'Bird (170).JPG'  'Clean (128).jpg'  'Dust (101).jpg'  'Snow (50).jpg'
# 'Bird (179).JPG'  'Clean (132).jpg'  'Dust (103).jpg'  'Snow (60).jpg'
# 'Bird (187).jpg'  'Clean (137).jpg'  'Dust (142).jpg'  'Snow (64).jpg'
# 'Bird (18).jpg'   'Clean (13).jpg'   'Dust (14).jpg'   'Snow (70).jpg'
# 'Bird (191).jpg'  'Clean (141).JPG'  'Dust (167).jpg'  'Snow (74).jpg'
# 'Bird (192).jpg'  'Clean (152).jpg'  'Dust (171).jpg'  'Snow (7).jpg'
# 'Bird (196).jpg'  'Clean (170).jpg'  'Dust (177).jpg'  'Snow (85).jpg'
# 'Bird (20).jpg'   'Clean (180).jpg'  'Dust (48).jpg'   'Snow (92).JPG'
# 'Bird (21).jpg'   'Clean (183).jpg'  'Dust (77).jpg'   'Snow (93).JPG'
# 'Bird (3).jpg'	  'Clean (23).jpg'   'Dust (85).jpg'   'Snow (9).jpg'
# 'Bird (41).jpg'   'Clean (2).jpg'    'Dust (91).jpg'

# %%
# Assuming you used an ImageDataGenerator originally like this:
from tensorflow.keras.preprocessing.image import ImageDataGenerator

test_dir = "/content/drive/MyDrive/Project/solarPanelDefectDetection_Binary/binaryClassification/test"

datagen = ImageDataGenerator(rescale=1./255)
test_gen = datagen.flow_from_directory(test_dir, target_size=(224,224), batch_size=1, class_mode='categorical')

print("Class indices:", test_gen.class_indices)
# Out:
# Found 89 images belonging to 2 classes.
# Class indices: {'defective': 0, 'non_defective': 1}

# %%
import numpy as np
from tensorflow.keras.preprocessing import image

def predict_with_ensemble(img_path, ensemble_models):
    # Load and preprocess the image
    img = image.load_img(img_path, target_size=(224, 224))
    img_array = image.img_to_array(img) / 255.0
    img_array = np.expand_dims(img_array, axis=0)

    # Collect predictions from all models
    preds = [model.predict(img_array, verbose=0)[0][0] for model in ensemble_models]
    avg_pred = np.mean(preds)

    print(f"Raw prediction probabilities: {avg_pred:.4f}")

    # Apply threshold (assuming 'defective':0, 'non_defective':1)
    if avg_pred > 0.5:
        print("Ensemble Prediction: Non-Defective")
    else:
        print("Ensemble Prediction: Defective")

    return avg_pred

# %%
img_path = "/content/drive/MyDrive/Project/solarPanelDefectDetection_Binary/binaryClassification/test/defective/Physical (64).jpg"
predict_with_ensemble(img_path, ensemble_models)
# Out:
# Raw prediction probabilities: 0.3839
# Ensemble Prediction: Defective
# np.float32(0.38394764)

# %%
img_path = "/content/drive/MyDrive/Project/solarPanelDefectDetection_Binary/binaryClassification/test/defective/Electrical (7).jpg"
predict_with_ensemble(img_path, ensemble_models)
# Out:
# Raw prediction probabilities: 0.3727
# Ensemble Prediction: Defective
# np.float32(0.37265697)

# %%
img_path = "/content/drive/MyDrive/Project/solarPanelDefectDetection_Binary/binaryClassification/test/non_defective/Clean (183).jpg"
predict_with_ensemble(img_path, ensemble_models)
# Out:
# Raw prediction probabilities: 0.6446
# Ensemble Prediction: Non-Defective
# np.float32(0.6446125)

# %%
img_path = "/content/drive/MyDrive/Project/solarPanelDefectDetection_Binary/binaryClassification/test/non_defective/Bird (77).jpg"
predict_with_ensemble(img_path, ensemble_models)
# Out:
# Raw prediction probabilities: 0.5968
# Ensemble Prediction: Non-Defective
# np.float32(0.5968124)

# %%
img_path = "/content/drive/MyDrive/Project/solarPanelDefectDetection_Binary/binaryClassification/test/non_defective/Dust (77).jpg"
predict_with_ensemble(img_path, ensemble_models)
# Out:
# Raw prediction probabilities: 0.6826
# Ensemble Prediction: Non-Defective
# np.float32(0.68263346)

# %%
img_path = "/content/drive/MyDrive/Project/solarPanelDefectDetection_Binary/binaryClassification/test/non_defective/Snow (9).jpg"
predict_with_ensemble(img_path, ensemble_models)
# Out:
# Raw prediction probabilities: 0.6429
# Ensemble Prediction: Non-Defective
# np.float32(0.6428608)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns
import os

# =====================================================
# 1️⃣ Load models (your code reused)
# =====================================================
from tensorflow.keras import backend as K

def focal_loss_fixed(y_true, y_pred, gamma=2., alpha=.25):
    eps = K.epsilon()
    y_pred = K.clip(y_pred, eps, 1. - eps)
    loss_pos = -alpha * K.pow(1 - y_pred, gamma) * y_true * K.log(y_pred)
    loss_neg = -(1 - alpha) * K.pow(y_pred, gamma) * (1 - y_true) * K.log(1 - y_pred)
    return K.sum(loss_pos + loss_neg, axis=1)

ensemble_dir = "/content/drive/MyDrive/Project/solarPanelDefectDetection_Binary/balancedClasses"
ensemble_models = []

for root, dirs, files in os.walk(ensemble_dir):
    for f in files:
        if f.endswith(".keras"):
            path = os.path.join(root, f)
            print(f"Loading {path}")
            model = tf.keras.models.load_model(path, custom_objects={'focal_loss_fixed': focal_loss_fixed})
            ensemble_models.append(model)

print(f"\nSuccessfully loaded {len(ensemble_models)} ensemble models.")

test_dir = "/content/drive/MyDrive/Project/solarPanelDefectDetection_Binary/binaryClassification/test"

test_datagen = ImageDataGenerator(rescale=1./255)
test_gen = test_datagen.flow_from_directory(
    test_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='binary',
    shuffle=False
)

all_preds = []
for model in ensemble_models:
    preds = model.predict(test_gen, verbose=0)
    all_preds.append(preds)

# Average predictions across all models (soft voting)
ensemble_preds = np.mean(np.array(all_preds), axis=0)

# Convert probabilities to binary classes
y_pred = (ensemble_preds > 0.5).astype(int).flatten()
y_true = test_gen.classes
acc = accuracy_score(y_true, y_pred)
print(f"\nEnsemble Test Accuracy: {acc*100:.2f}%")

print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=test_gen.class_indices.keys()))

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=test_gen.class_indices.keys(),
            yticklabels=test_gen.class_indices.keys())
plt.title("Ensemble Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

plt.figure(figsize=(6,4))
plt.hist(ensemble_preds[y_true==0], bins=25, alpha=0.7, label="Defective (True 0)")
plt.hist(ensemble_preds[y_true==1], bins=25, alpha=0.7, label="Non-Defective (True 1)")
plt.title("Prediction Probability Distribution")
plt.xlabel("Predicted Probability (Non-Defective)")
plt.ylabel("Frequency")
plt.legend()
plt.show()
# Out:
# Loading /content/drive/MyDrive/Project/solarPanelDefectDetection_Binary/balancedClasses/model_results/SplitBalanced_batch_1_ResNet50.keras
# Loading /content/drive/MyDrive/Project/solarPanelDefectDetection_Binary/balancedClasses/model_results/SplitBalanced_batch_1_VGG16.keras
# Loading /content/drive/MyDrive/Project/solarPanelDefectDetection_Binary/balancedClasses/model_results/SplitBalanced_batch_1_InceptionV3.keras
# Loading /content/drive/MyDrive/Project/solarPanelDefectDetection_Binary/balancedClasses/model_results/SplitBalanced_batch_1_EfficientNetB0.keras
# Loading /content/drive/MyDrive/Project/solarPanelDefectDetection_Binary/balancedClasses/model_results/SplitBalanced_batch_1_MobileNetV2.keras
# Loading /content/drive/MyDrive/Project/solarPanelDefectDetection_Binary/balancedClasses/model_results/SplitBalanced_batch_2_ResNet50.keras
# Loading /content/drive/MyDrive/Project/solarPanelDefectDetection_Binary/balancedClasses/model_results/SplitBalanced_batch_2_VGG16.keras
# Loading /content/drive/MyDrive/Project/solarPanelDefectDetection_Binary/balancedClasses/model_results/SplitBalanced_batch_2_InceptionV3.keras
# Loading /content/drive/MyDrive/Project/solarPanelDefectDetection_Binary/balancedClasses/model_results/SplitBalanced_batch_2_EfficientNetB0.keras
# Loading /content/drive/MyDrive/Project/solarPanelDefectDetection_Binary/balancedClasses/model_results/SplitBalanced_batch_2_MobileNetV2.keras
# Loading /content/drive/MyDrive/Project/solarPanelDefectDetection_Binary/balancedClasses/model_results/SplitBalanced_batch_3_ResNet50.keras
# Loading /content/drive/MyDrive/Project/solarPanelDefectDetection_Binary/balancedClasses/model_results/SplitBalanced_batch_3_VGG16.keras
# Loading /content/drive/MyDrive/Project/solarPanelDefectDetection_Binary/balancedClasses/model_results/SplitBalanced_batch_3_InceptionV3.keras
# Loading /content/drive/MyDrive/Project/solarPanelDefectDetection_Binary/balancedClasses/model_results/SplitBalanced_batch_3_EfficientNetB0.keras
# Loading /content/drive/MyDrive/Project/solarPanelDefectDetection_Binary/balancedClasses/model_results/SplitBalanced_batch_3_MobileNetV2.keras
# Loading /content/drive/MyDrive/Project/solarPanelDefectDetection_Binary/balancedClasses/model_results/SplitBalanced_batch_4_ResNet50.keras
# Loading /content/drive/MyDrive/Project/solarPanelDefectDetection_Binary/balancedClasses/model_results/SplitBalanced_batch_4_VGG16.keras
# Loading /content/drive/MyDrive/Project/solarPanelDefectDetection_Binary/balancedClasses/model_results/SplitBalanced_batch_4_InceptionV3.keras
# Loading /content/drive/MyDrive/Project/solarPanelDefectDetection_Binary/balancedClasses/model_results/SplitBalanced_batch_4_EfficientNetB0.keras
# Loading /content/drive/MyDrive/Project/solarPanelDefectDetection_Binary/balancedClasses/model_results/SplitBalanced_batch_4_MobileNetV2.keras
# Loading /content/drive/MyDrive/Project/solarPanelDefectDetection_Binary/balancedClasses/model_results/SplitBalanced_batch_3_Ensemble.keras
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:802: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 90 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:802: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 70 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:802: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 52 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:802: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 74 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:802: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 82 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Successfully loaded 21 ensemble models.
# Found 89 images belonging to 2 classes.
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING:tensorflow:5 out of the last 7 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7fcc2c178540> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7fcc2c178540> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
# !ls -R /content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized
# Out:
# /content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized:
# Classification	Defective  Non-Defective
#
# /content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized/Classification:
# test  train  val
#
# /content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized/Classification/test:
# Defective  Non-Defective
#
# /content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized/Classification/test/Defective:
# Electrical-damage  Physical-Damage
#
# /content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized/Classification/test/Defective/Electrical-damage:
# 'Electrical (14).jpg'  'Electrical (2).png'   'Electrical (57).JPG'
# 'Electrical (18).jpg'  'Electrical (34).jpg'  'Electrical (75).jpg'
# 'Electrical (1).jpg'   'Electrical (4).JPG'   'Electrical (9).jpg'
# 'Electrical (28).jpg'  'Electrical (54).jpg'
#
# /content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized/Classification/test/Defective/Physical-Damage:
# 'Physical (18).jpg'  'Physical (37).jpg'  'Physical (66).jpg'
# 'Physical (26).JPG'  'Physical (3).jpg'   'Physical (69).jpg'
# 'Physical (29).jpg'  'Physical (5).jpg'
#
# /content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized/Classification/test/Non-Defective:
# Clean  Non-Clean
#
# /content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized/Classification/test/Non-Defective/Clean:
# 'Clean (105).jpg'  'Clean (143).jpg'  'Clean (176).jpg'  'Clean (33).jpg'
# 'Clean (106).jpg'  'Clean (144).jpg'  'Clean (180).jpg'  'Clean (50).jpg'
# 'Clean (113).jpg'  'Clean (15).JPG'   'Clean (184).jpg'  'Clean (63).jpg'
# 'Clean (123).jpg'  'Clean (168).jpg'  'Clean (21).jpg'	 'Clean (76).jpg'
# 'Clean (140).JPG'  'Clean (172).jpg'  'Clean (27).jpg'	 'Clean (94).jpg'
#
# /content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized/Classification/test/Non-Defective/Non-Clean:
# Bird-drop  Dusty  Snow-Covered
#
# /content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized/Classification/test/Non-Defective/Non-Clean/Bird-drop:
# 'Bird (100).jpg'  'Bird (120).jpg'  'Bird (24).JPG'  'Bird (63).jpg'   New
# 'Bird (104).jpg'  'Bird (131).jpg'  'Bird (28).jpg'  'Bird (80).jpg'
# 'Bird (106).jpg'  'Bird (142).jpg'  'Bird (3).jpeg'  'Bird (88).jpg'
# 'Bird (108).jpg'  'Bird (18).jpg'   'Bird (5).jpg'   'Bird (8).jpg'
# 'Bird (119).jpg'  'Bird (198).JPG'  'Bird (60).jpg'  'Bird (99).jpg'
#
# /content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized/Classification/test/Non-Defective/Non-Clean/Bird-drop/New:
# 16.JPG	4.JPG
#
# /content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized/Classification/test/Non-Defective/Non-Clean/Dusty:
# 'Dust (112).jpg'  'Dust (166).jpg'  'Dust (43).jpg'  'Dust (77).jpg'
# 'Dust (131).jpg'  'Dust (168).jpg'  'Dust (61).jpg'  'Dust (89).jpg'
# 'Dust (162).jpg'  'Dust (174).jpg'  'Dust (65).jpg'  'Dust (91).jpg'
# 'Dust (163).jpg'  'Dust (183).jpg'  'Dust (68).jpg'  'Dust (95).jpg'
# 'Dust (164).jpg'  'Dust (40).jpg'   'Dust (6).jpg'
#
# /content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized/Classification/test/Non-Defective/Non-Clean/Snow-Covered:
# 'Snow (103).jpg'  'Snow (2).jpg'   'Snow (51).jpg'  'Snow (95).jpg'
# 'Snow (120).jpg'  'Snow (30).JPG'  'Snow (5).jpg'
# 'Snow (13).jpg'   'Snow (47).jpg'  'Snow (61).jpg'
# 'Snow (1).jpg'	  'Snow (4).jpg'   'Snow (7).jpg'
#
# /content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized/Classification/train:
# Defective  Non-Defective
#
# /content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized/Classification/train/Defective:
# Electrical-damage  Physical-Damage
#
# /content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized/Classification/train/Defective/Electrical-damage:
# 'Electrical (10).jpg'  'Electrical (40).jpg'  'Electrical (70).jpg'
# 'Electrical (12).jpg'  'Electrical (41).jpg'  'Electrical (71).jpg'
# 'Electrical (15).jpg'  'Electrical (42).jpg'  'Electrical (72).jpg'
# 'Electrical (16).jpg'  'Electrical (43).jpg'  'Electrical (73).JPG'
# 'Electrical (17).jpg'  'Electrical (44).jpg'  'Electrical (74).jpg'
# 'Electrical (1).png'   'Electrical (45).jpg'  'Electrical (76).jpg'
# 'Electrical (20).jpg'  'Electrical (46).jpg'  'Electrical (77).jpg'
# 'Electrical (21).jpg'  'Electrical (47).jpg'  'Electrical (78).jpg'
# 'Electrical (22).jpg'  'Electrical (48).jpg'  'Electrical (79).jpg'
# 'Electrical (23).jpg'  'Electrical (4).png'   'Electrical (7).jpg'
# 'Electrical (24).jpg'  'Electrical (50).jpg'  'Electrical (82).jpg'
# 'Electrical (25).jpg'  'Electrical (51).jpg'  'Electrical (85).JPG'
# 'Electrical (26).jpg'  'Electrical (52).jpg'  'Electrical (86).JPG'
# 'Electrical (27).jpg'  'Electrical (56).jpg'  'Electrical (87).jpg'
# 'Electrical (29).jpg'  'Electrical (58).jpg'  'Electrical (88).jpg'
# 'Electrical (2).JPG'   'Electrical (59).jpg'  'Electrical (89).jpg'
# 'Electrical (31).jpg'  'Electrical (60).jpg'  'Electrical (8).jpg'
# 'Electrical (32).jpg'  'Electrical (61).jpg'  'Electrical (90).jpg'
# 'Electrical (33).jpg'  'Electrical (62).jpg'  'Electrical (91).jpg'
# 'Electrical (35).jpg'  'Electrical (64).JPG'  'Electrical (93).jpg'
# 'Electrical (38).jpg'  'Electrical (65).JPG'  'Electrical (94).jpg'
# 'Electrical (39).jpg'  'Electrical (66).JPG'  'Electrical (96).jpg'
# 'Electrical (3).JPG'   'Electrical (68).JPG'  'Electrical (97).jpg'
# 'Electrical (3).png'   'Electrical (69).jpg'  'Electrical (99).jpg'
#
# /content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized/Classification/train/Defective/Physical-Damage:
# 'Physical (10).jpg'  'Physical (31).jpg'  'Physical (52).JPG'
# 'Physical (11).jpg'  'Physical (32).jpg'  'Physical (53).jpg'
# 'Physical (12).jpg'  'Physical (33).jpg'  'Physical (54).jpg'
# 'Physical (14).jpg'  'Physical (35).jpg'  'Physical (55).jpg'
# 'Physical (15).jpg'  'Physical (36).jpg'  'Physical (56).jpg'
# 'Physical (16).jpg'  'Physical (38).jpg'  'Physical (57).jpg'
# 'Physical (19).jpg'  'Physical (40).jpg'  'Physical (59).jpg'
# 'Physical (1).jpg'   'Physical (41).jpg'  'Physical (60).jpg'
# 'Physical (20).jpg'  'Physical (44).jpg'  'Physical (62).jpg'
# 'Physical (21).jpg'  'Physical (45).jpg'  'Physical (64).jpg'
# 'Physical (23).jpg'  'Physical (46).jpg'  'Physical (65).jpg'
# 'Physical (24).jpg'  'Physical (48).jpg'  'Physical (67).jpg'
# 'Physical (25).jpg'  'Physical (49).jpg'  'Physical (6).jpg'
# 'Physical (28).jpg'  'Physical (4).jpg'   'Physical (7).jpg'
# 'Physical (2).jpg'   'Physical (50).jpg'  'Physical (8).jpg'
# 'Physical (30).jpg'  'Physical (51).jpg'  'Physical (9).jpg'
#
# /content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized/Classification/train/Non-Defective:
# Clean  Non-Clean
#
# /content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized/Classification/train/Non-Defective/Clean:
# 'Clean (100).jpg'  'Clean (158).jpg'  'Clean (24).jpg'	'Clean (66).jpg'
# 'Clean (101).jpg'  'Clean (159).jpg'  'Clean (25).jpg'	'Clean (69).jpg'
# 'Clean (102).jpg'  'Clean (160).jpg'  'Clean (26).jpg'	'Clean (6).jpg'
# 'Clean (103).jpg'  'Clean (162).jpg'  'Clean (28).jpg'	'Clean (70).jpg'
# 'Clean (104).jpg'  'Clean (163).jpg'  'Clean (29).jpg'	'Clean (72).jpg'
# 'Clean (108).jpg'  'Clean (164).jpg'  'Clean (2).jpg'	'Clean (73).jpg'
# 'Clean (109).jpg'  'Clean (165).jpg'  'Clean (30).jpg'	'Clean (74).jpg'
# 'Clean (10).JPG'   'Clean (166).jpg'  'Clean (31).jpg'	'Clean (75).jpg'
# 'Clean (110).jpg'  'Clean (167).jpg'  'Clean (32).jpg'	'Clean (77).jpg'
# 'Clean (111).jpg'  'Clean (169).jpg'  'Clean (34).jpg'	'Clean (78).jpg'
# 'Clean (112).jpg'  'Clean (170).jpg'  'Clean (35).jpg'	'Clean (79).jpg'
# 'Clean (114).jpg'  'Clean (171).jpg'  'Clean (37).jpg'	'Clean (7).jpg'
# 'Clean (115).jpg'  'Clean (173).jpg'  'Clean (38).jpg'	'Clean (80).jpg'
# 'Clean (116).jpg'  'Clean (174).jpg'  'Clean (39).jpg'	'Clean (81).jpg'
# 'Clean (117).jpg'  'Clean (175).jpg'  'Clean (40).jpg'	'Clean (82).jpg'
# 'Clean (118).jpg'  'Clean (177).jpg'  'Clean (41).jpg'	'Clean (83).jpg'
# 'Clean (11).jpg'   'Clean (178).jpg'  'Clean (43).jpg'	'Clean (84).jpg'
# 'Clean (122).jpg'  'Clean (179).jpg'  'Clean (44).jpg'	'Clean (85).jpg'
# 'Clean (124).jpg'  'Clean (17).jpg'   'Clean (45).jpg'	'Clean (86).jpg'
# 'Clean (127).jpg'  'Clean (182).jpg'  'Clean (46).jpg'	'Clean (87).jpg'
# 'Clean (132).jpg'  'Clean (183).jpg'  'Clean (4).jpg'	'Clean (88).jpg'
# 'Clean (133).jpg'  'Clean (186).jpg'  'Clean (51).jpg'	'Clean (89).jpg'
# 'Clean (137).jpg'  'Clean (187).jpg'  'Clean (52).jpg'	'Clean (8).jpg'
# 'Clean (139).JPG'  'Clean (188).jpg'  'Clean (53).jpg'	'Clean (90).jpg'
# 'Clean (141).JPG'  'Clean (189).jpg'  'Clean (55).jpg'	'Clean (91).jpg'
# 'Clean (142).jpg'  'Clean (18).jpg'   'Clean (56).jpg'	'Clean (92).jpg'
# 'Clean (145).jpg'  'Clean (190).jpg'  'Clean (57).jpg'	'Clean (93).jpg'
# 'Clean (146).jpg'  'Clean (191).jpg'  'Clean (58).jpg'	'Clean (95).jpg'
# 'Clean (147).jpg'  'Clean (192).jpg'  'Clean (5).jpg'	'Clean (96).jpg'
# 'Clean (148).jpg'  'Clean (193).png'  'Clean (60).jpg'	'Clean (97).jpg'
# 'Clean (151).jpg'  'Clean (1).jpeg'   'Clean (61).jpg'	'Clean (98).jpg'
# 'Clean (155).jpg'  'Clean (20).jpg'   'Clean (62).jpg'	'Clean (99).jpg'
# 'Clean (156).jpg'  'Clean (22).jpg'   'Clean (64).jpg'	'Clean (9).jpg'
# 'Clean (157).jpg'  'Clean (23).jpg'   'Clean (65).jpg'
#
# /content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized/Classification/train/Non-Defective/Non-Clean:
# Bird-drop  Dusty  Snow-Covered
#
# /content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized/Classification/train/Non-Defective/Non-Clean/Bird-drop:
# 'Bird (101).jpg'  'Bird (150).jpg'  'Bird (195).jpg'  'Bird (54).jpg'
# 'Bird (105).jpg'  'Bird (159).jpg'  'Bird (196).jpg'  'Bird (55).jpg'
# 'Bird (107).jpg'  'Bird (15).JPG'   'Bird (197).jpg'  'Bird (57).jpg'
# 'Bird (109).jpg'  'Bird (160).jpg'  'Bird (19).jpg'   'Bird (59).jpg'
# 'Bird (111).jpg'  'Bird (161).jpg'  'Bird (1).jpeg'   'Bird (61).jpg'
# 'Bird (115).jpg'  'Bird (162).jpg'  'Bird (21).jpg'   'Bird (62).jpg'
# 'Bird (116).jpg'  'Bird (163).jpg'  'Bird (22).jpg'   'Bird (65).jpg'
# 'Bird (117).jpg'  'Bird (164).jpg'  'Bird (23).JPG'   'Bird (66).jpg'
# 'Bird (118).jpg'  'Bird (165).jpg'  'Bird (25).jpg'   'Bird (69).JPG'
# 'Bird (11).jpg'   'Bird (166).jpg'  'Bird (27).JPG'   'Bird (6).jpg'
# 'Bird (121).jpg'  'Bird (168).jpg'  'Bird (2).JPG'    'Bird (72).jpg'
# 'Bird (122).jpg'  'Bird (169).jpg'  'Bird (30).jpg'   'Bird (73).jpg'
# 'Bird (124).jpg'  'Bird (16).JPG'   'Bird (31).JPG'   'Bird (74).jpg'
# 'Bird (125).jpg'  'Bird (170).JPG'  'Bird (32).JPG'   'Bird (76).jpg'
# 'Bird (126).jpg'  'Bird (172).jpg'  'Bird (33).jpg'   'Bird (77).jpg'
# 'Bird (128).jpg'  'Bird (173).jpg'  'Bird (35).jpg'   'Bird (78).jpg'
# 'Bird (129).jpg'  'Bird (174).jpg'  'Bird (36).jpg'   'Bird (79).jpg'
# 'Bird (12).jpg'   'Bird (176).jpg'  'Bird (37).jpg'   'Bird (7).jpg'
# 'Bird (130).jpg'  'Bird (177).jpg'  'Bird (38).jpg'   'Bird (81).jpg'
# 'Bird (132).jpg'  'Bird (179).JPG'  'Bird (39).jpg'   'Bird (83).jpg'
# 'Bird (133).jpg'  'Bird (17).jpg'   'Bird (3).jpg'    'Bird (85).jpg'
# 'Bird (134).JPG'  'Bird (180).jpg'  'Bird (40).jpg'   'Bird (86).jpg'
# 'Bird (136).JPG'  'Bird (182).jpg'  'Bird (41).jpg'   'Bird (89).jpg'
# 'Bird (137).JPG'  'Bird (183).jpg'  'Bird (42).jpg'   'Bird (90).jpg'
# 'Bird (139).jpg'  'Bird (184).jpg'  'Bird (43).jpg'   'Bird (92).jpg'
# 'Bird (13).jpg'   'Bird (185).jpg'  'Bird (44).jpg'   'Bird (94).jpg'
# 'Bird (140).jpg'  'Bird (186).jpg'  'Bird (46).jpg'   'Bird (95).jpg'
# 'Bird (143).jpg'  'Bird (187).jpg'  'Bird (47).jpg'   'Bird (96).jpg'
# 'Bird (144).jpg'  'Bird (188).jpg'  'Bird (48).jpg'   'Bird (97).jpg'
# 'Bird (145).jpg'  'Bird (189).jpg'  'Bird (49).jpg'   'Bird (98).jpg'
# 'Bird (147).jpg'  'Bird (190).jpg'  'Bird (4).jpg'    'Bird (9).jpg'
# 'Bird (148).jpg'  'Bird (192).jpg'  'Bird (50).jpg'    New
# 'Bird (149).jpg'  'Bird (193).jpg'  'Bird (51).jpg'
# 'Bird (14).JPG'   'Bird (194).jpg'  'Bird (53).jpg'
#
# /content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized/Classification/train/Non-Defective/Non-Clean/Bird-drop/New:
# 10.JPG	12.JPG	15.JPG	3.JPG  7.JPG  9.JPG
# 11.JPG	14.JPG	2.JPG	5.JPG  8.JPG
#
# /content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized/Classification/train/Non-Defective/Non-Clean/Dusty:
# 'Dust (100).jpg'  'Dust (142).jpg'  'Dust (187).jpg'  'Dust (58).jpg'
# 'Dust (102).jpg'  'Dust (143).jpg'  'Dust (188).jpg'  'Dust (59).jpg'
# 'Dust (103).jpg'  'Dust (144).jpg'  'Dust (18).jpg'   'Dust (5).jpg'
# 'Dust (104).jpg'  'Dust (146).jpg'  'Dust (190).jpg'  'Dust (60).jpg'
# 'Dust (105).jpg'  'Dust (147).jpg'  'Dust (19).jpg'   'Dust (62).jpg'
# 'Dust (106).jpg'  'Dust (148).jpg'  'Dust (1).jpg'    'Dust (63).jpg'
# 'Dust (107).jpg'  'Dust (14).jpg'   'Dust (21).jpg'   'Dust (66).jpg'
# 'Dust (108).jpg'  'Dust (150).jpg'  'Dust (22).jpg'   'Dust (70).jpg'
# 'Dust (109).jpg'  'Dust (151).jpg'  'Dust (24).jpg'   'Dust (71).jpg'
# 'Dust (110).jpg'  'Dust (152).jpg'  'Dust (26).jpg'   'Dust (72).jpg'
# 'Dust (111).jpg'  'Dust (153).jpg'  'Dust (27).jpg'   'Dust (73).jpg'
# 'Dust (113).jpg'  'Dust (154).jpg'  'Dust (2).jpg'    'Dust (75).jpg'
# 'Dust (116).jpg'  'Dust (156).jpg'  'Dust (30).jpg'   'Dust (76).jpg'
# 'Dust (117).jpg'  'Dust (157).jpg'  'Dust (31).jpg'   'Dust (78).jpg'
# 'Dust (118).jpg'  'Dust (159).jpg'  'Dust (32).jpg'   'Dust (79).jpg'
# 'Dust (119).jpg'  'Dust (15).jpg'   'Dust (34).jpg'   'Dust (7).jpg'
# 'Dust (121).jpg'  'Dust (160).jpg'  'Dust (35).jpg'   'Dust (80).jpg'
# 'Dust (123).jpg'  'Dust (161).jpg'  'Dust (36).jpg'   'Dust (81).jpg'
# 'Dust (124).jpg'  'Dust (165).jpg'  'Dust (37).jpg'   'Dust (82).jpg'
# 'Dust (125).jpg'  'Dust (169).jpg'  'Dust (38).jpg'   'Dust (83).jpg'
# 'Dust (127).jpg'  'Dust (16).jpg'   'Dust (3).jpg'    'Dust (84).jpg'
# 'Dust (128).jpg'  'Dust (170).jpg'  'Dust (41).jpg'   'Dust (85).jpg'
# 'Dust (129).jpg'  'Dust (171).jpg'  'Dust (42).jpg'   'Dust (86).jpg'
# 'Dust (12).jpg'   'Dust (172).jpg'  'Dust (44).jpg'   'Dust (87).jpg'
# 'Dust (133).jpg'  'Dust (173).jpg'  'Dust (46).jpg'   'Dust (88).jpg'
# 'Dust (134).jpg'  'Dust (175).jpg'  'Dust (47).jpg'   'Dust (8).jpg'
# 'Dust (135).jpg'  'Dust (176).jpg'  'Dust (49).jpg'   'Dust (92).jpg'
# 'Dust (136).jpg'  'Dust (178).jpg'  'Dust (50).jpg'   'Dust (93).jpg'
# 'Dust (137).jpg'  'Dust (179).jpg'  'Dust (52).jpg'   'Dust (96).jpg'
# 'Dust (138).jpg'  'Dust (17).jpg'   'Dust (53).jpg'   'Dust (97).jpg'
# 'Dust (139).jpg'  'Dust (180).jpg'  'Dust (54).jpg'   'Dust (9).jpg'
# 'Dust (13).jpg'   'Dust (181).jpg'  'Dust (55).jpg'
# 'Dust (140).jpg'  'Dust (182).jpg'  'Dust (56).jpg'
# 'Dust (141).jpg'  'Dust (186).jpg'  'Dust (57).jpg'
#
# /content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized/Classification/train/Non-Defective/Non-Clean/Snow-Covered:
# 'Snow (100).jpg'  'Snow (17).jpg'  'Snow (43).jpg'  'Snow (72).jpg'
# 'Snow (101).jpg'  'Snow (18).jpg'  'Snow (46).jpg'  'Snow (73).jpg'
# 'Snow (102).jpg'  'Snow (19).jpg'  'Snow (49).jpg'  'Snow (74).jpg'
# 'Snow (105).jpg'  'Snow (20).jpg'  'Snow (50).jpg'  'Snow (75).jpg'
# 'Snow (106).jpg'  'Snow (21).jpg'  'Snow (52).jpg'  'Snow (76).jpg'
# 'Snow (108).jpg'  'Snow (22).jpg'  'Snow (53).jpg'  'Snow (77).JPG'
# 'Snow (109).jpg'  'Snow (23).jpg'  'Snow (54).jpg'  'Snow (78).jpg'
# 'Snow (10).jpg'   'Snow (24).jpg'  'Snow (55).jpg'  'Snow (79).jpg'
# 'Snow (110).jpg'  'Snow (25).jpg'  'Snow (56).jpg'  'Snow (80).jpg'
# 'Snow (111).jpg'  'Snow (26).jpg'  'Snow (57).jpg'  'Snow (81).JPG'
# 'Snow (112).jpg'  'Snow (29).JPG'  'Snow (58).jpg'  'Snow (82).JPG'
# 'Snow (113).jpg'  'Snow (31).JPG'  'Snow (59).jpg'  'Snow (83).jpg'
# 'Snow (114).jpg'  'Snow (32).JPG'  'Snow (60).jpg'  'Snow (84).jpg'
# 'Snow (117).jpg'  'Snow (33).JPG'  'Snow (62).jpg'  'Snow (85).jpg'
# 'Snow (118).jpg'  'Snow (34).jpg'  'Snow (63).jpg'  'Snow (88).JPG'
# 'Snow (119).jpg'  'Snow (35).JPG'  'Snow (64).jpg'  'Snow (92).JPG'
# 'Snow (121).jpg'  'Snow (36).JPG'  'Snow (65).jpg'  'Snow (94).jpg'
# 'Snow (122).jpg'  'Snow (37).jpg'  'Snow (67).jpg'  'Snow (97).jpg'
# 'Snow (123).jpg'  'Snow (39).JPG'  'Snow (68).jpg'  'Snow (99).jpg'
# 'Snow (12).jpg'   'Snow (3).jpg'   'Snow (69).jpg'  'Snow (9).jpg'
# 'Snow (14).jpg'   'Snow (40).JPG'  'Snow (70).jpg'
# 'Snow (16).jpg'   'Snow (42).jpg'  'Snow (71).jpg'
#
# /content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized/Classification/val:
# Defective  Non-Defective
#
# /content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized/Classification/val/Defective:
# Electrical-damage  Physical-Damage
#
# /content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized/Classification/val/Defective/Electrical-damage:
# 'Electrical (11).jpg'  'Electrical (53).JPG'  'Electrical (81).jpg'
# 'Electrical (13).jpg'  'Electrical (55).jpg'  'Electrical (83).jpg'
# 'Electrical (19).jpg'  'Electrical (5).jpg'   'Electrical (84).jpg'
# 'Electrical (30).jpg'  'Electrical (63).jpg'  'Electrical (92).jpg'
# 'Electrical (36).jpg'  'Electrical (67).JPG'  'Electrical (95).jpg'
# 'Electrical (37).jpg'  'Electrical (6).jpg'   'Electrical (98).jpg'
# 'Electrical (49).jpg'  'Electrical (80).jpg'
#
# /content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized/Classification/val/Defective/Physical-Damage:
# 'Physical (13).jpg'  'Physical (39).jpg'  'Physical (61).jpg'
# 'Physical (17).jpg'  'Physical (42).jpg'  'Physical (63).jpg'
# 'Physical (22).jpg'  'Physical (43).jpg'  'Physical (68).jpg'
# 'Physical (27).JPG'  'Physical (47).jpg'
# 'Physical (34).jpg'  'Physical (58).jpg'
#
# /content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized/Classification/val/Non-Defective:
# Clean  Non-Clean
#
# /content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized/Classification/val/Non-Defective/Clean:
# 'Clean (107).jpg'  'Clean (131).jpg'  'Clean (153).jpg'  'Clean (47).jpg'
# 'Clean (119).jpg'  'Clean (134).jpg'  'Clean (154).jpg'  'Clean (48).jpg'
# 'Clean (120).jpg'  'Clean (135).JPG'  'Clean (161).jpg'  'Clean (49).jpg'
# 'Clean (121).jpg'  'Clean (136).JPG'  'Clean (16).JPG'	 'Clean (54).jpg'
# 'Clean (125).jpg'  'Clean (138).jpg'  'Clean (181).jpg'  'Clean (59).jpg'
# 'Clean (126).jpg'  'Clean (13).jpg'   'Clean (185).jpg'  'Clean (67).jpg'
# 'Clean (128).jpg'  'Clean (149).jpg'  'Clean (19).jpg'	 'Clean (68).jpg'
# 'Clean (129).jpg'  'Clean (14).jpg'   'Clean (36).jpg'	 'Clean (71).jpg'
# 'Clean (12).jpg'   'Clean (150).jpg'  'Clean (3).jpg'
# 'Clean (130).jpg'  'Clean (152).jpg'  'Clean (42).jpg'
#
# /content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized/Classification/val/Non-Defective/Non-Clean:
# Bird-drop  Dusty  Snow-Covered
#
# /content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized/Classification/val/Non-Defective/Non-Clean/Bird-drop:
# 'Bird (102).jpg'  'Bird (138).JPG'  'Bird (26).JPG'  'Bird (70).jpg'
# 'Bird (103).jpg'  'Bird (141).jpg'  'Bird (29).jpg'  'Bird (71).jpg'
# 'Bird (10).jpg'   'Bird (146).jpg'  'Bird (34).jpg'  'Bird (75).jpg'
# 'Bird (110).jpg'  'Bird (167).JPG'  'Bird (45).jpg'  'Bird (82).jpg'
# 'Bird (112).jpg'  'Bird (171).JPG'  'Bird (52).jpg'  'Bird (84).jpg'
# 'Bird (113).jpg'  'Bird (175).jpg'  'Bird (56).jpg'  'Bird (87).jpg'
# 'Bird (114).jpg'  'Bird (178).jpg'  'Bird (58).jpg'  'Bird (91).jpg'
# 'Bird (123).jpg'  'Bird (181).jpg'  'Bird (64).jpg'  'Bird (93).jpg'
# 'Bird (127).jpg'  'Bird (191).jpg'  'Bird (67).jpg'   New
# 'Bird (135).jpg'  'Bird (20).jpg'   'Bird (68).jpg'
#
# /content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized/Classification/val/Non-Defective/Non-Clean/Bird-drop/New:
# 13.JPG	1.JPG  6.JPG
#
# /content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized/Classification/val/Non-Defective/Non-Clean/Dusty:
# 'Dust (101).jpg'  'Dust (145).jpg'  'Dust (23).jpg'  'Dust (64).jpg'
# 'Dust (10).jpg'   'Dust (149).jpg'  'Dust (25).jpg'  'Dust (67).jpg'
# 'Dust (114).jpg'  'Dust (155).jpg'  'Dust (28).jpg'  'Dust (69).jpg'
# 'Dust (115).jpg'  'Dust (158).jpg'  'Dust (29).jpg'  'Dust (74).jpg'
# 'Dust (11).jpg'   'Dust (167).jpg'  'Dust (33).jpg'  'Dust (90).jpg'
# 'Dust (120).jpg'  'Dust (177).jpg'  'Dust (39).jpg'  'Dust (94).jpg'
# 'Dust (122).jpg'  'Dust (184).jpg'  'Dust (45).jpg'  'Dust (98).jpg'
# 'Dust (126).jpg'  'Dust (185).jpg'  'Dust (48).jpg'  'Dust (99).jpg'
# 'Dust (130).jpg'  'Dust (189).jpg'  'Dust (4).jpg'
# 'Dust (132).jpg'  'Dust (20).jpg'   'Dust (51).jpg'
#
# /content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized/Classification/val/Non-Defective/Non-Clean/Snow-Covered:
# 'Snow (104).jpg'  'Snow (27).jpg'  'Snow (48).jpg'  'Snow (8).jpg'
# 'Snow (107).jpg'  'Snow (28).JPG'  'Snow (66).jpg'  'Snow (90).jpg'
# 'Snow (115).jpg'  'Snow (38).jpg'  'Snow (6).jpg'   'Snow (91).JPG'
# 'Snow (116).jpg'  'Snow (41).jpg'  'Snow (86).jpg'  'Snow (93).JPG'
# 'Snow (11).jpg'   'Snow (44).jpg'  'Snow (87).JPG'  'Snow (96).jpg'
# 'Snow (15).jpg'   'Snow (45).jpg'  'Snow (89).jpg'  'Snow (98).jpg'
#
# /content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized/Defective:
# Electrical-damage  Physical-Damage
#
# /content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized/Defective/Electrical-damage:
#  desktop.ini	       'Electrical (3).JPG'   'Electrical (6).jpg'
# 'Electrical (10).jpg'  'Electrical (3).png'   'Electrical (70).jpg'
# 'Electrical (11).jpg'  'Electrical (40).jpg'  'Electrical (71).jpg'
# 'Electrical (12).jpg'  'Electrical (41).jpg'  'Electrical (72).jpg'
# 'Electrical (13).jpg'  'Electrical (42).jpg'  'Electrical (73).JPG'
# 'Electrical (14).jpg'  'Electrical (43).jpg'  'Electrical (74).jpg'
# 'Electrical (15).jpg'  'Electrical (44).jpg'  'Electrical (75).jpg'
# 'Electrical (16).jpg'  'Electrical (45).jpg'  'Electrical (76).jpg'
# 'Electrical (17).jpg'  'Electrical (46).jpg'  'Electrical (77).jpg'
# 'Electrical (18).jpg'  'Electrical (47).jpg'  'Electrical (78).jpg'
# 'Electrical (19).jpg'  'Electrical (48).jpg'  'Electrical (79).jpg'
# 'Electrical (1).jpg'   'Electrical (49).jpg'  'Electrical (7).jpg'
# 'Electrical (1).png'   'Electrical (4).JPG'   'Electrical (80).jpg'
# 'Electrical (20).jpg'  'Electrical (4).png'   'Electrical (81).jpg'
# 'Electrical (21).jpg'  'Electrical (50).jpg'  'Electrical (82).jpg'
# 'Electrical (22).jpg'  'Electrical (51).jpg'  'Electrical (83).jpg'
# 'Electrical (23).jpg'  'Electrical (52).jpg'  'Electrical (84).jpg'
# 'Electrical (24).jpg'  'Electrical (53).JPG'  'Electrical (85).JPG'
# 'Electrical (25).jpg'  'Electrical (54).jpg'  'Electrical (86).JPG'
# 'Electrical (26).jpg'  'Electrical (55).jpg'  'Electrical (87).jpg'
# 'Electrical (27).jpg'  'Electrical (56).jpg'  'Electrical (88).jpg'
# 'Electrical (28).jpg'  'Electrical (57).JPG'  'Electrical (89).jpg'
# 'Electrical (29).jpg'  'Electrical (58).jpg'  'Electrical (8).jpg'
# 'Electrical (2).JPG'   'Electrical (59).jpg'  'Electrical (90).jpg'
# 'Electrical (2).png'   'Electrical (5).jpg'   'Electrical (91).jpg'
# 'Electrical (30).jpg'  'Electrical (60).jpg'  'Electrical (92).jpg'
# 'Electrical (31).jpg'  'Electrical (61).jpg'  'Electrical (93).jpg'
# 'Electrical (32).jpg'  'Electrical (62).jpg'  'Electrical (94).jpg'
# 'Electrical (33).jpg'  'Electrical (63).jpg'  'Electrical (95).jpg'
# 'Electrical (34).jpg'  'Electrical (64).JPG'  'Electrical (96).jpg'
# 'Electrical (35).jpg'  'Electrical (65).JPG'  'Electrical (97).jpg'
# 'Electrical (36).jpg'  'Electrical (66).JPG'  'Electrical (98).jpg'
# 'Electrical (37).jpg'  'Electrical (67).JPG'  'Electrical (99).jpg'
# 'Electrical (38).jpg'  'Electrical (68).JPG'  'Electrical (9).jpg'
# 'Electrical (39).jpg'  'Electrical (69).jpg'
#
# /content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized/Defective/Physical-Damage:
#  desktop.ini	     'Physical (31).jpg'  'Physical (53).jpg'
# 'Physical (10).jpg'  'Physical (32).jpg'  'Physical (54).jpg'
# 'Physical (11).jpg'  'Physical (33).jpg'  'Physical (55).jpg'
# 'Physical (12).jpg'  'Physical (34).jpg'  'Physical (56).jpg'
# 'Physical (13).jpg'  'Physical (35).jpg'  'Physical (57).jpg'
# 'Physical (14).jpg'  'Physical (36).jpg'  'Physical (58).jpg'
# 'Physical (15).jpg'  'Physical (37).jpg'  'Physical (59).jpg'
# 'Physical (16).jpg'  'Physical (38).jpg'  'Physical (5).jpg'
# 'Physical (17).jpg'  'Physical (39).jpg'  'Physical (60).jpg'
# 'Physical (18).jpg'  'Physical (3).jpg'   'Physical (61).jpg'
# 'Physical (19).jpg'  'Physical (40).jpg'  'Physical (62).jpg'
# 'Physical (1).jpg'   'Physical (41).jpg'  'Physical (63).jpg'
# 'Physical (20).jpg'  'Physical (42).jpg'  'Physical (64).jpg'
# 'Physical (21).jpg'  'Physical (43).jpg'  'Physical (65).jpg'
# 'Physical (22).jpg'  'Physical (44).jpg'  'Physical (66).jpg'
# 'Physical (23).jpg'  'Physical (45).jpg'  'Physical (67).jpg'
# 'Physical (24).jpg'  'Physical (46).jpg'  'Physical (68).jpg'
# 'Physical (25).jpg'  'Physical (47).jpg'  'Physical (69).jpg'
# 'Physical (26).JPG'  'Physical (48).jpg'  'Physical (6).jpg'
# 'Physical (27).JPG'  'Physical (49).jpg'  'Physical (7).jpg'
# 'Physical (28).jpg'  'Physical (4).jpg'   'Physical (8).jpg'
# 'Physical (29).jpg'  'Physical (50).jpg'  'Physical (9).jpg'
# 'Physical (2).jpg'   'Physical (51).jpg'
# 'Physical (30).jpg'  'Physical (52).JPG'
#
# /content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized/Non-Defective:
# Clean  Non-Clean
#
# /content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized/Non-Defective/Clean:
# 'Clean (100).jpg'  'Clean (145).jpg'  'Clean (18).jpg'	 'Clean (59).jpg'
# 'Clean (101).jpg'  'Clean (146).jpg'  'Clean (190).jpg'  'Clean (5).jpg'
# 'Clean (102).jpg'  'Clean (147).jpg'  'Clean (191).jpg'  'Clean (60).jpg'
# 'Clean (103).jpg'  'Clean (148).jpg'  'Clean (192).jpg'  'Clean (61).jpg'
# 'Clean (104).jpg'  'Clean (149).jpg'  'Clean (193).png'  'Clean (62).jpg'
# 'Clean (105).jpg'  'Clean (14).jpg'   'Clean (19).jpg'	 'Clean (63).jpg'
# 'Clean (106).jpg'  'Clean (150).jpg'  'Clean (1).jpeg'	 'Clean (64).jpg'
# 'Clean (107).jpg'  'Clean (151).jpg'  'Clean (20).jpg'	 'Clean (65).jpg'
# 'Clean (108).jpg'  'Clean (152).jpg'  'Clean (21).jpg'	 'Clean (66).jpg'
# 'Clean (109).jpg'  'Clean (153).jpg'  'Clean (22).jpg'	 'Clean (67).jpg'
# 'Clean (10).JPG'   'Clean (154).jpg'  'Clean (23).jpg'	 'Clean (68).jpg'
# 'Clean (110).jpg'  'Clean (155).jpg'  'Clean (24).jpg'	 'Clean (69).jpg'
# 'Clean (111).jpg'  'Clean (156).jpg'  'Clean (25).jpg'	 'Clean (6).jpg'
# 'Clean (112).jpg'  'Clean (157).jpg'  'Clean (26).jpg'	 'Clean (70).jpg'
# 'Clean (113).jpg'  'Clean (158).jpg'  'Clean (27).jpg'	 'Clean (71).jpg'
# 'Clean (114).jpg'  'Clean (159).jpg'  'Clean (28).jpg'	 'Clean (72).jpg'
# 'Clean (115).jpg'  'Clean (15).JPG'   'Clean (29).jpg'	 'Clean (73).jpg'
# 'Clean (116).jpg'  'Clean (160).jpg'  'Clean (2).jpg'	 'Clean (74).jpg'
# 'Clean (117).jpg'  'Clean (161).jpg'  'Clean (30).jpg'	 'Clean (75).jpg'
# 'Clean (118).jpg'  'Clean (162).jpg'  'Clean (31).jpg'	 'Clean (76).jpg'
# 'Clean (119).jpg'  'Clean (163).jpg'  'Clean (32).jpg'	 'Clean (77).jpg'
# 'Clean (11).jpg'   'Clean (164).jpg'  'Clean (33).jpg'	 'Clean (78).jpg'
# 'Clean (120).jpg'  'Clean (165).jpg'  'Clean (34).jpg'	 'Clean (79).jpg'
# 'Clean (121).jpg'  'Clean (166).jpg'  'Clean (35).jpg'	 'Clean (7).jpg'
# 'Clean (122).jpg'  'Clean (167).jpg'  'Clean (36).jpg'	 'Clean (80).jpg'
# 'Clean (123).jpg'  'Clean (168).jpg'  'Clean (37).jpg'	 'Clean (81).jpg'
# 'Clean (124).jpg'  'Clean (169).jpg'  'Clean (38).jpg'	 'Clean (82).jpg'
# 'Clean (125).jpg'  'Clean (16).JPG'   'Clean (39).jpg'	 'Clean (83).jpg'
# 'Clean (126).jpg'  'Clean (170).jpg'  'Clean (3).jpg'	 'Clean (84).jpg'
# 'Clean (127).jpg'  'Clean (171).jpg'  'Clean (40).jpg'	 'Clean (85).jpg'
# 'Clean (128).jpg'  'Clean (172).jpg'  'Clean (41).jpg'	 'Clean (86).jpg'
# 'Clean (129).jpg'  'Clean (173).jpg'  'Clean (42).jpg'	 'Clean (87).jpg'
# 'Clean (12).jpg'   'Clean (174).jpg'  'Clean (43).jpg'	 'Clean (88).jpg'
# 'Clean (130).jpg'  'Clean (175).jpg'  'Clean (44).jpg'	 'Clean (89).jpg'
# 'Clean (131).jpg'  'Clean (176).jpg'  'Clean (45).jpg'	 'Clean (8).jpg'
# 'Clean (132).jpg'  'Clean (177).jpg'  'Clean (46).jpg'	 'Clean (90).jpg'
# 'Clean (133).jpg'  'Clean (178).jpg'  'Clean (47).jpg'	 'Clean (91).jpg'
# 'Clean (134).jpg'  'Clean (179).jpg'  'Clean (48).jpg'	 'Clean (92).jpg'
# 'Clean (135).JPG'  'Clean (17).jpg'   'Clean (49).jpg'	 'Clean (93).jpg'
# 'Clean (136).JPG'  'Clean (180).jpg'  'Clean (4).jpg'	 'Clean (94).jpg'
# 'Clean (137).jpg'  'Clean (181).jpg'  'Clean (50).jpg'	 'Clean (95).jpg'
# 'Clean (138).jpg'  'Clean (182).jpg'  'Clean (51).jpg'	 'Clean (96).jpg'
# 'Clean (139).JPG'  'Clean (183).jpg'  'Clean (52).jpg'	 'Clean (97).jpg'
# 'Clean (13).jpg'   'Clean (184).jpg'  'Clean (53).jpg'	 'Clean (98).jpg'
# 'Clean (140).JPG'  'Clean (185).jpg'  'Clean (54).jpg'	 'Clean (99).jpg'
# 'Clean (141).JPG'  'Clean (186).jpg'  'Clean (55).jpg'	 'Clean (9).jpg'
# 'Clean (142).jpg'  'Clean (187).jpg'  'Clean (56).jpg'	  desktop.ini
# 'Clean (143).jpg'  'Clean (188).jpg'  'Clean (57).jpg'
# 'Clean (144).jpg'  'Clean (189).jpg'  'Clean (58).jpg'
#
# /content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized/Non-Defective/Non-Clean:
# Bird-drop  Dusty  Snow-Covered
#
# /content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized/Non-Defective/Non-Clean/Bird-drop:
# 'Bird (100).jpg'  'Bird (145).jpg'  'Bird (197).jpg'  'Bird (60).jpg'
# 'Bird (101).jpg'  'Bird (146).jpg'  'Bird (198).JPG'  'Bird (61).jpg'
# 'Bird (102).jpg'  'Bird (147).jpg'  'Bird (19).jpg'   'Bird (62).jpg'
# 'Bird (103).jpg'  'Bird (148).jpg'  'Bird (1).jpeg'   'Bird (63).jpg'
# 'Bird (104).jpg'  'Bird (149).jpg'  'Bird (20).jpg'   'Bird (64).jpg'
# 'Bird (105).jpg'  'Bird (14).JPG'   'Bird (21).jpg'   'Bird (65).jpg'
# 'Bird (106).jpg'  'Bird (150).jpg'  'Bird (22).jpg'   'Bird (66).jpg'
# 'Bird (107).jpg'  'Bird (159).jpg'  'Bird (23).JPG'   'Bird (67).jpg'
# 'Bird (108).jpg'  'Bird (15).JPG'   'Bird (24).JPG'   'Bird (68).jpg'
# 'Bird (109).jpg'  'Bird (160).jpg'  'Bird (25).jpg'   'Bird (69).JPG'
# 'Bird (10).jpg'   'Bird (161).jpg'  'Bird (26).JPG'   'Bird (6).jpg'
# 'Bird (110).jpg'  'Bird (162).jpg'  'Bird (27).JPG'   'Bird (70).jpg'
# 'Bird (111).jpg'  'Bird (163).jpg'  'Bird (28).jpg'   'Bird (71).jpg'
# 'Bird (112).jpg'  'Bird (164).jpg'  'Bird (29).jpg'   'Bird (72).jpg'
# 'Bird (113).jpg'  'Bird (165).jpg'  'Bird (2).JPG'    'Bird (73).jpg'
# 'Bird (114).jpg'  'Bird (166).jpg'  'Bird (30).jpg'   'Bird (74).jpg'
# 'Bird (115).jpg'  'Bird (167).JPG'  'Bird (31).JPG'   'Bird (75).jpg'
# 'Bird (116).jpg'  'Bird (168).jpg'  'Bird (32).JPG'   'Bird (76).jpg'
# 'Bird (117).jpg'  'Bird (169).jpg'  'Bird (33).jpg'   'Bird (77).jpg'
# 'Bird (118).jpg'  'Bird (16).JPG'   'Bird (34).jpg'   'Bird (78).jpg'
# 'Bird (119).jpg'  'Bird (170).JPG'  'Bird (35).jpg'   'Bird (79).jpg'
# 'Bird (11).jpg'   'Bird (171).JPG'  'Bird (36).jpg'   'Bird (7).jpg'
# 'Bird (120).jpg'  'Bird (172).jpg'  'Bird (37).jpg'   'Bird (80).jpg'
# 'Bird (121).jpg'  'Bird (173).jpg'  'Bird (38).jpg'   'Bird (81).jpg'
# 'Bird (122).jpg'  'Bird (174).jpg'  'Bird (39).jpg'   'Bird (82).jpg'
# 'Bird (123).jpg'  'Bird (175).jpg'  'Bird (3).jpeg'   'Bird (83).jpg'
# 'Bird (124).jpg'  'Bird (176).jpg'  'Bird (3).jpg'    'Bird (84).jpg'
# 'Bird (125).jpg'  'Bird (177).jpg'  'Bird (40).jpg'   'Bird (85).jpg'
# 'Bird (126).jpg'  'Bird (178).jpg'  'Bird (41).jpg'   'Bird (86).jpg'
# 'Bird (127).jpg'  'Bird (179).JPG'  'Bird (42).jpg'   'Bird (87).jpg'
# 'Bird (128).jpg'  'Bird (17).jpg'   'Bird (43).jpg'   'Bird (88).jpg'
# 'Bird (129).jpg'  'Bird (180).jpg'  'Bird (44).jpg'   'Bird (89).jpg'
# 'Bird (12).jpg'   'Bird (181).jpg'  'Bird (45).jpg'   'Bird (8).jpg'
# 'Bird (130).jpg'  'Bird (182).jpg'  'Bird (46).jpg'   'Bird (90).jpg'
# 'Bird (131).jpg'  'Bird (183).jpg'  'Bird (47).jpg'   'Bird (91).jpg'
# 'Bird (132).jpg'  'Bird (184).jpg'  'Bird (48).jpg'   'Bird (92).jpg'
# 'Bird (133).jpg'  'Bird (185).jpg'  'Bird (49).jpg'   'Bird (93).jpg'
# 'Bird (134).JPG'  'Bird (186).jpg'  'Bird (4).jpg'    'Bird (94).jpg'
# 'Bird (135).jpg'  'Bird (187).jpg'  'Bird (50).jpg'   'Bird (95).jpg'
# 'Bird (136).JPG'  'Bird (188).jpg'  'Bird (51).jpg'   'Bird (96).jpg'
# 'Bird (137).JPG'  'Bird (189).jpg'  'Bird (52).jpg'   'Bird (97).jpg'
# 'Bird (138).JPG'  'Bird (18).jpg'   'Bird (53).jpg'   'Bird (98).jpg'
# 'Bird (139).jpg'  'Bird (190).jpg'  'Bird (54).jpg'   'Bird (99).jpg'
# 'Bird (13).jpg'   'Bird (191).jpg'  'Bird (55).jpg'   'Bird (9).jpg'
# 'Bird (140).jpg'  'Bird (192).jpg'  'Bird (56).jpg'    desktop.ini
# 'Bird (141).jpg'  'Bird (193).jpg'  'Bird (57).jpg'    New
# 'Bird (142).jpg'  'Bird (194).jpg'  'Bird (58).jpg'
# 'Bird (143).jpg'  'Bird (195).jpg'  'Bird (59).jpg'
# 'Bird (144).jpg'  'Bird (196).jpg'  'Bird (5).jpg'
#
# /content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized/Non-Defective/Non-Clean/Bird-drop/New:
# 10.JPG	12.JPG	14.JPG	16.JPG	2.JPG  4.JPG  6.JPG  8.JPG
# 11.JPG	13.JPG	15.JPG	1.JPG	3.JPG  5.JPG  7.JPG  9.JPG
#
# /content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized/Non-Defective/Non-Clean/Dusty:
#  desktop.ini	  'Dust (143).jpg'  'Dust (187).jpg'  'Dust (58).jpg'
# 'Dust (100).jpg'  'Dust (144).jpg'  'Dust (188).jpg'  'Dust (59).jpg'
# 'Dust (101).jpg'  'Dust (145).jpg'  'Dust (189).jpg'  'Dust (5).jpg'
# 'Dust (102).jpg'  'Dust (146).jpg'  'Dust (18).jpg'   'Dust (60).jpg'
# 'Dust (103).jpg'  'Dust (147).jpg'  'Dust (190).jpg'  'Dust (61).jpg'
# 'Dust (104).jpg'  'Dust (148).jpg'  'Dust (19).jpg'   'Dust (62).jpg'
# 'Dust (105).jpg'  'Dust (149).jpg'  'Dust (1).jpg'    'Dust (63).jpg'
# 'Dust (106).jpg'  'Dust (14).jpg'   'Dust (20).jpg'   'Dust (64).jpg'
# 'Dust (107).jpg'  'Dust (150).jpg'  'Dust (21).jpg'   'Dust (65).jpg'
# 'Dust (108).jpg'  'Dust (151).jpg'  'Dust (22).jpg'   'Dust (66).jpg'
# 'Dust (109).jpg'  'Dust (152).jpg'  'Dust (23).jpg'   'Dust (67).jpg'
# 'Dust (10).jpg'   'Dust (153).jpg'  'Dust (24).jpg'   'Dust (68).jpg'
# 'Dust (110).jpg'  'Dust (154).jpg'  'Dust (25).jpg'   'Dust (69).jpg'
# 'Dust (111).jpg'  'Dust (155).jpg'  'Dust (26).jpg'   'Dust (6).jpg'
# 'Dust (112).jpg'  'Dust (156).jpg'  'Dust (27).jpg'   'Dust (70).jpg'
# 'Dust (113).jpg'  'Dust (157).jpg'  'Dust (28).jpg'   'Dust (71).jpg'
# 'Dust (114).jpg'  'Dust (158).jpg'  'Dust (29).jpg'   'Dust (72).jpg'
# 'Dust (115).jpg'  'Dust (159).jpg'  'Dust (2).jpg'    'Dust (73).jpg'
# 'Dust (116).jpg'  'Dust (15).jpg'   'Dust (30).jpg'   'Dust (74).jpg'
# 'Dust (117).jpg'  'Dust (160).jpg'  'Dust (31).jpg'   'Dust (75).jpg'
# 'Dust (118).jpg'  'Dust (161).jpg'  'Dust (32).jpg'   'Dust (76).jpg'
# 'Dust (119).jpg'  'Dust (162).jpg'  'Dust (33).jpg'   'Dust (77).jpg'
# 'Dust (11).jpg'   'Dust (163).jpg'  'Dust (34).jpg'   'Dust (78).jpg'
# 'Dust (120).jpg'  'Dust (164).jpg'  'Dust (35).jpg'   'Dust (79).jpg'
# 'Dust (121).jpg'  'Dust (165).jpg'  'Dust (36).jpg'   'Dust (7).jpg'
# 'Dust (122).jpg'  'Dust (166).jpg'  'Dust (37).jpg'   'Dust (80).jpg'
# 'Dust (123).jpg'  'Dust (167).jpg'  'Dust (38).jpg'   'Dust (81).jpg'
# 'Dust (124).jpg'  'Dust (168).jpg'  'Dust (39).jpg'   'Dust (82).jpg'
# 'Dust (125).jpg'  'Dust (169).jpg'  'Dust (3).jpg'    'Dust (83).jpg'
# 'Dust (126).jpg'  'Dust (16).jpg'   'Dust (40).jpg'   'Dust (84).jpg'
# 'Dust (127).jpg'  'Dust (170).jpg'  'Dust (41).jpg'   'Dust (85).jpg'
# 'Dust (128).jpg'  'Dust (171).jpg'  'Dust (42).jpg'   'Dust (86).jpg'
# 'Dust (129).jpg'  'Dust (172).jpg'  'Dust (43).jpg'   'Dust (87).jpg'
# 'Dust (12).jpg'   'Dust (173).jpg'  'Dust (44).jpg'   'Dust (88).jpg'
# 'Dust (130).jpg'  'Dust (174).jpg'  'Dust (45).jpg'   'Dust (89).jpg'
# 'Dust (131).jpg'  'Dust (175).jpg'  'Dust (46).jpg'   'Dust (8).jpg'
# 'Dust (132).jpg'  'Dust (176).jpg'  'Dust (47).jpg'   'Dust (90).jpg'
# 'Dust (133).jpg'  'Dust (177).jpg'  'Dust (48).jpg'   'Dust (91).jpg'
# 'Dust (134).jpg'  'Dust (178).jpg'  'Dust (49).jpg'   'Dust (92).jpg'
# 'Dust (135).jpg'  'Dust (179).jpg'  'Dust (4).jpg'    'Dust (93).jpg'
# 'Dust (136).jpg'  'Dust (17).jpg'   'Dust (50).jpg'   'Dust (94).jpg'
# 'Dust (137).jpg'  'Dust (180).jpg'  'Dust (51).jpg'   'Dust (95).jpg'
# 'Dust (138).jpg'  'Dust (181).jpg'  'Dust (52).jpg'   'Dust (96).jpg'
# 'Dust (139).jpg'  'Dust (182).jpg'  'Dust (53).jpg'   'Dust (97).jpg'
# 'Dust (13).jpg'   'Dust (183).jpg'  'Dust (54).jpg'   'Dust (98).jpg'
# 'Dust (140).jpg'  'Dust (184).jpg'  'Dust (55).jpg'   'Dust (99).jpg'
# 'Dust (141).jpg'  'Dust (185).jpg'  'Dust (56).jpg'   'Dust (9).jpg'
# 'Dust (142).jpg'  'Dust (186).jpg'  'Dust (57).jpg'
#
# /content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized/Non-Defective/Non-Clean/Snow-Covered:
#  desktop.ini	  'Snow (16).jpg'  'Snow (44).jpg'  'Snow (72).jpg'
# 'Snow (100).jpg'  'Snow (17).jpg'  'Snow (45).jpg'  'Snow (73).jpg'
# 'Snow (101).jpg'  'Snow (18).jpg'  'Snow (46).jpg'  'Snow (74).jpg'
# 'Snow (102).jpg'  'Snow (19).jpg'  'Snow (47).jpg'  'Snow (75).jpg'
# 'Snow (103).jpg'  'Snow (1).jpg'   'Snow (48).jpg'  'Snow (76).jpg'
# 'Snow (104).jpg'  'Snow (20).jpg'  'Snow (49).jpg'  'Snow (77).JPG'
# 'Snow (105).jpg'  'Snow (21).jpg'  'Snow (4).jpg'   'Snow (78).jpg'
# 'Snow (106).jpg'  'Snow (22).jpg'  'Snow (50).jpg'  'Snow (79).jpg'
# 'Snow (107).jpg'  'Snow (23).jpg'  'Snow (51).jpg'  'Snow (7).jpg'
# 'Snow (108).jpg'  'Snow (24).jpg'  'Snow (52).jpg'  'Snow (80).jpg'
# 'Snow (109).jpg'  'Snow (25).jpg'  'Snow (53).jpg'  'Snow (81).JPG'
# 'Snow (10).jpg'   'Snow (26).jpg'  'Snow (54).jpg'  'Snow (82).JPG'
# 'Snow (110).jpg'  'Snow (27).jpg'  'Snow (55).jpg'  'Snow (83).jpg'
# 'Snow (111).jpg'  'Snow (28).JPG'  'Snow (56).jpg'  'Snow (84).jpg'
# 'Snow (112).jpg'  'Snow (29).JPG'  'Snow (57).jpg'  'Snow (85).jpg'
# 'Snow (113).jpg'  'Snow (2).jpg'   'Snow (58).jpg'  'Snow (86).jpg'
# 'Snow (114).jpg'  'Snow (30).JPG'  'Snow (59).jpg'  'Snow (87).JPG'
# 'Snow (115).jpg'  'Snow (31).JPG'  'Snow (5).jpg'   'Snow (88).JPG'
# 'Snow (116).jpg'  'Snow (32).JPG'  'Snow (60).jpg'  'Snow (89).jpg'
# 'Snow (117).jpg'  'Snow (33).JPG'  'Snow (61).jpg'  'Snow (8).jpg'
# 'Snow (118).jpg'  'Snow (34).jpg'  'Snow (62).jpg'  'Snow (90).jpg'
# 'Snow (119).jpg'  'Snow (35).JPG'  'Snow (63).jpg'  'Snow (91).JPG'
# 'Snow (11).jpg'   'Snow (36).JPG'  'Snow (64).jpg'  'Snow (92).JPG'
# 'Snow (120).jpg'  'Snow (37).jpg'  'Snow (65).jpg'  'Snow (93).JPG'
# 'Snow (121).jpg'  'Snow (38).jpg'  'Snow (66).jpg'  'Snow (94).jpg'
# 'Snow (122).jpg'  'Snow (39).JPG'  'Snow (67).jpg'  'Snow (95).jpg'
# 'Snow (123).jpg'  'Snow (3).jpg'   'Snow (68).jpg'  'Snow (96).jpg'
# 'Snow (12).jpg'   'Snow (40).JPG'  'Snow (69).jpg'  'Snow (97).jpg'
# 'Snow (13).jpg'   'Snow (41).jpg'  'Snow (6).jpg'   'Snow (98).jpg'
# 'Snow (14).jpg'   'Snow (42).jpg'  'Snow (70).jpg'  'Snow (99).jpg'
# 'Snow (15).jpg'   'Snow (43).jpg'  'Snow (71).jpg'  'Snow (9).jpg'

# %%
import os
import pandas as pd
#Update this path if needed
base_dir = "/content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized"
# Supported image extensions
image_exts = ('.jpg', '.jpeg', '.png', '.JPG', '.PNG')
# Store results here
counts = []
# Walk through all directories
for root, dirs, files in os.walk(base_dir):
    image_files = [f for f in files if f.endswith(image_exts)]
    if image_files:
        counts.append({
            "Folder": root.replace(base_dir + "/", ""),
            "Image_Count": len(image_files)
        })
# Convert to DataFrame for easy viewing
df_counts = pd.DataFrame(counts).sort_values(by="Folder").reset_index(drop=True)
print("Image Counts per Folder:")
display(df_counts)
df_counts.to_csv("/content/image_counts.csv", index=False)
print("\nSaved counts to '/content/image_counts.csv'")
# Out:
# Image Counts per Folder:
#                                                Folder  Image_Count
# 0     Classification/test/Defective/Electrical-damage           11
# 1       Classification/test/Defective/Physical-Damage            8
# 2             Classification/test/Non-Defective/Clean           20
# 3   Classification/test/Non-Defective/Non-Clean/Bi...           20
# 4   Classification/test/Non-Defective/Non-Clean/Bi...            2
# 5   Classification/test/Non-Defective/Non-Clean/Dusty           19
# 6   Classification/test/Non-Defective/Non-Clean/Sn...           13
# 7    Classification/train/Defective/Electrical-damage           72
# 8      Classification/train/Defective/Physical-Damage           48
# 9            Classification/train/Non-Defective/Clean          135
# 10  Classification/train/Non-Defective/Non-Clean/B...          133
# 11  Classification/train/Non-Defective/Non-Clean/B...           11
# 12  Classification/train/Non-Defective/Non-Clean/D...          133
# 13  Classification/train/Non-Defective/Non-Clean/S...           86
# 14     Classification/val/Defective/Electrical-damage           20
# 15       Classification/val/Defective/Physical-Damage           13
# 16             Classification/val/Non-Defective/Clean           38
# 17  Classification/val/Non-Defective/Non-Clean/Bir...           38
# 18  Classification/val/Non-Defective/Non-Clean/Bir...            3
# 19   Classification/val/Non-Defective/Non-Clean/Dusty           38
# 20  Classification/val/Non-Defective/Non-Clean/Sno...           24
# 21                        Defective/Electrical-damage          103
# 22                          Defective/Physical-Damage           69
# 23                                Non-Defective/Clean          193
# 24                  Non-Defective/Non-Clean/Bird-drop          191
# 25              Non-Defective/Non-Clean/Bird-drop/New           16
# 26                      Non-Defective/Non-Clean/Dusty          190
# 27               Non-Defective/Non-Clean/Snow-Covered          123
# Saved counts to '/content/image_counts.csv'

# %%
import os
import shutil
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array, save_img

def balance_by_augment_safe(minority_dir, target_count, output_dir):
    # --- Step 1: Copy original folder to new location ---
    if os.path.exists(output_dir):
        print(f"Output folder already exists at {output_dir}")
    else:
        shutil.copytree(minority_dir, output_dir)
        print(f"Copied {minority_dir} -> {output_dir}")

    # --- Step 2: Work only inside the copied folder ---
    exts = ('.jpg','.jpeg','.png','.JPG','.PNG')
    existing = [f for f in os.listdir(output_dir) if f.endswith(exts)]
    current = len(existing)
    print("Current:", current, "Target:", target_count)
    if current >= target_count:
        print("Already balanced or larger. No augmentation needed.")
        return

    datagen = ImageDataGenerator(
        rotation_range=25,
        width_shift_range=0.08,
        height_shift_range=0.08,
        shear_range=0.08,
        zoom_range=0.12,
        horizontal_flip=True,
        fill_mode='nearest'
    )

    idx = 0
    while current < target_count:
        for fname in existing:
            if current >= target_count:
                break
            img_path = os.path.join(output_dir, fname)
            try:
                img = load_img(img_path, target_size=(224,224))
                x = img_to_array(img)
                x = x.reshape((1,) + x.shape)
                gen = datagen.flow(x, batch_size=1)
                for _ in range(2):
                    batch = next(gen)
                    out_name = f"aug_{idx}_{fname}"
                    save_img(os.path.join(output_dir, out_name), batch[0])
                    idx += 1
                    current += 1
                    if current >= target_count:
                        break
            except Exception as e:
                print("skip", img_path, e)
        existing = [f for f in os.listdir(output_dir) if f.endswith(exts)]
    print("Done. New count:", current)

# --- Run safely ---
original = "/content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized/Defective/Physical-Damage"
augmented_copy = "/content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized/Defective/augmentedPhysical-Damage"
majority_count = 103

balance_by_augment_safe(original, majority_count, augmented_copy)
# Out:
# Copied /content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized/Defective/Physical-Damage -> /content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized/Defective/augmentedPhysical-Damage
# Current: 69 Target: 103
# Done. New count: 103

# %%
import os
import shutil

base_path = "/content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized/Defective"
target_dir = "/content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized/Defective_Augmented"

# Create the new combined folder
os.makedirs(target_dir, exist_ok=True)

# Paths for source folders
electrical_src = os.path.join(base_path, "Electrical-damage")
physical_src = os.path.join(base_path, "augmentedPhysical-Damage")

# Create class folders inside the target
electrical_dst = os.path.join(target_dir, "Electrical-damage")
physical_dst = os.path.join(target_dir, "Physical-Damage")

os.makedirs(electrical_dst, exist_ok=True)
os.makedirs(physical_dst, exist_ok=True)

# Copy images
for src, dst in [(electrical_src, electrical_dst), (physical_src, physical_dst)]:
    for fname in os.listdir(src):
        fpath = os.path.join(src, fname)
        if os.path.isfile(fpath):
            shutil.copy(fpath, dst)

print("Combined dataset created at:", target_dir)
# Out:
# Combined dataset created at: /content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized/Defective_Augmented

# %%
# !pip install -q split-folders
import splitfolders
input_folder = "/content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized/Defective_Augmented"
output_folder = "/content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized/Defective_Augmented/Defective_split_balanced"
splitfolders.ratio(
    input_folder,
    output=output_folder,
    seed=1337,
    ratio=(0.7, 0.15, 0.15)
)
print("Split created at:", output_folder)
# Out:
# Copying files: 208 files [00:06, 33.33 files/s]
# Split created at: /content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized/Defective_Augmented/Defective_split_balanced

# %%
# !ls /content/drive/MyDrive/Project
# Out:
# solarPanelDefectDetection_Binary  solarPanelDefectDetection_Reorganized

# %%
# !ls /content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized/Defective_Augmented
# Out:
# Defective_split_balanced  Electrical-damage  Physical-Damage

# %%
import os
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import (
    VGG16, ResNet50, InceptionV3, MobileNetV2, EfficientNetB0
)
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
base_dir = "/content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized/Defective_Augmented/Defective_split_balanced"
save_dir = "/content/drive/MyDrive/Project/solarPanelDefectDetection_Reorganized/Defective_Augmented/Defective_split_balanced/model_results"
os.makedirs(save_dir, exist_ok=True)
img_size = (224, 224)
batch_size = 32
num_classes = 2  # Electrical-damage vs Physical-Damage

# %%
train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)
train_gen = train_datagen.flow_from_directory(
    os.path.join(base_dir, 'train'),
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical'
)
val_gen = val_datagen.flow_from_directory(
    os.path.join(base_dir, 'val'),
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical'
)
test_gen = test_datagen.flow_from_directory(
    os.path.join(base_dir, 'test'),
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 142 images belonging to 2 classes.
# Found 30 images belonging to 2 classes.
# Found 34 images belonging to 2 classes.
